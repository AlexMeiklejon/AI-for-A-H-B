# %% [markdown]
# # AI for Arts Portfolio
#
# ## 1. Context
# ## 1.1 Chosen Object
# ## 1.2 Objectives
#
# ## 2. Design Approach
# ## 2.1 Method
# ## 2.2 Why AI
#
# ## 3. Implementation
# ## 3.1 Building the Dataset
# ## 3.2 Mapping the Archive
#
# ## 4. Critical Reflection
#
# ## 5. References
